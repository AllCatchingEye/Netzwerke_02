# %%
from typing import List, Tuple
import logging as log
from datetime import datetime
import matplotlib.ticker as ticker
import matplotlib.animation as animation
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

y = [0.8698500440528634,
0.9735275273355073,
0.8678635677127035,
0.9025403239556692,
1.047163064453879]

x = [1.1659726353361095,
1.208791208791209,
1.2176319430717533,
1.232,
1.2357787367595134]

median_x = np.median(x)
median_y = np.median(y)
std_x = np.std(x)
std_y = np.std(y)

print(median_x)
print(median_y)
#print(std_x)
#print(std_y)

plt.plot(x, y, '-ok')
plt.plot(median_x, median_y, '-ok')
plt.xlabel('Senderate kB/s')
plt.ylabel('Empfangsrate kB/s')
#plt.plot(std_x, std_y, '-ok')
plt.show()
# Out:
# 1.2176319430717533
# 0.9025403239556692

# %%
x = [0.8960631004,
0.96477775651,
0.98178727000,
1.01171855469,
1.01210256898
]

y = [0.94745222930,
1.00358422939,
1.04664000000,
1.03125622138,
1.05367399485
]
	
median_x = np.median(x)
median_y = np.median(y)
var_x = np.std(x)
var_y = np.std(y)

plt.plot(x, y, '-ok')
plt.plot(median_x, median_y, 'ok')
plt.xlabel('Senderate kB/s')
plt.ylabel('Empfangsrate kB/s')
plt.show()

# %%
tcp_server = [
    1.4739200000000001,
    1.5718095238095238,
    2.090222222222222,
    2.5216,
    2.3695,
    2.539733333333333,
    3.7496,
    4.279111111111112,
    3.9095999999999997,
    5.547428571428571
]

tcp_sender = [
    1.6,
    2.1052631578947367,
    2.2222222222222223,
    2.6666666666666665,
    2.6666666666666665,
    2.6666666666666665,
    4.0,
    5.0,
    5.0,
    5.714285714285714
]

median_server = np.median(tcp_server)
median_sender = np.median(tcp_sender)
std_server = np.std(tcp_server)
std_sender = np.std(tcp_sender)

plt.plot(tcp_sender, tcp_server, '-ok')
plt.xlabel('Senderate kB/s')
plt.ylabel('Empfangsrate kB/s')
plt.title('TCP Localhosot')
plt.show()
