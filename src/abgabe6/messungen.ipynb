# %%
from typing import List, Tuple
import logging as log
from datetime import datetime
import matplotlib.ticker as ticker
import matplotlib.animation as animation
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

server = [
36.34809014903671,
37.642613628502254,
43.02632581818182,
42.99748899799964,
43.31372332303217,
44.04071101417666,
48.25100745319033,
48.504144000000004,
48.46275077258681,
49.09516394038531,
]

sender = [
40.08928,
43.67328,
47.42976,
47.47904,
47.73216,
48.48256,
53.099199999999996,
53.36128,
53.39264,
54.0736,
]

median_sender = np.median(sender)
median_server = np.median(server)
std_sender = np.std(sender)
std_server = np.std(server)

print("Medianwert von Sender: " + str(median_sender))
print("Medianwert von Server: " + str(median_server))
print("Standardabweichung von Sender: " + str(std_sender))
print("Standardabweichung von Server: " + str(std_server))

plt.plot(sender, server, '-ok')
plt.xlabel('Senderate kB/s')
plt.ylabel('Empfangsrate kB/s')
plt.title('UDP Localhost')
#plt.plot(std_x, std_y, '-ok')
plt.show()
# Out:
# Medianwert von Sender: 1.2176319430717533
# Medianwert von Server: 0.9025403239556692
# Standardabweichung von Sender: 0.025003822315172734
# Standardabweichung von Server: 0.06903746808505776

# %%
sender = [0.8960631004,
0.96477775651,
0.98178727000,
1.01171855469,
1.01210256898
]

server = [0.94745222930,
1.00358422939,
1.04664000000,
1.03125622138,
1.05367399485
]
	
median_x = np.median(sender)
median_y = np.median(server)
std_x = np.std(sender)
std_y = np.std(server)

print("Medianwert von Sender: " + str(median_sender))
print("Medianwert von Server: " + str(median_server))
print("Standardabweichung von Sender: " + str(std_sender))
print("Standardabweichung von Server: " + str(std_server))

plt.plot(sender, server, '-ok')
plt.title('UDP Netzwerk')
plt.xlabel('Senderate kB/s')
plt.ylabel('Empfangsrate kB/s')
plt.show()
# Out:
# Medianwert von Sender: 1.2176319430717533
# Medianwert von Server: 0.9025403239556692
# Standardabweichung von Sender: 0.025003822315172734
# Standardabweichung von Server: 0.06903746808505776

# %%
tcp_server = [
1870.5279136000001,
2073.6844775044992,
2216.3539984,
2246.5656832,
2347.0519360000003,
2418.0608137627523,
2424.892296,
2470.3519616,
2470.8600784,
2495.1019504
]

tcp_sender = [
1871.8649599999999,
2075.166726654669,
2217.9382400000004,
2248.17152,
2348.7296,
2419.3052799999996,
2426.6256000000003,
2472.1177599999996,
2472.62624,
2496.88544
]

median_server = np.median(tcp_server)
median_sender = np.median(tcp_sender)
std_server = np.std(tcp_server)
std_sender = np.std(tcp_sender)

print("Medianwert von Sender: " + str(median_sender))
print("Medianwert von Server: " + str(median_server))
print("Standardabweichung von Sender: " + str(std_sender))
print("Standardabweichung von Server: " + str(std_server))

plt.plot(tcp_sender, tcp_server, '-ok')
plt.xlabel('Senderate kB/s')
plt.ylabel('Empfangsrate kB/s')
plt.title('TCP Localhost')
plt.show()
# Out:
# Medianwert von Sender: 2384.0174399999996
# Medianwert von Server: 2382.5563748813765
# Standardabweichung von Sender: 193.35360765364533
# Standardabweichung von Server: 193.24415259867882

# %%
tcp_server = [
37.63648044692737,
312.989174025974,
421.4941984,
459.4003996802558,
497.8822678928429,
499.00594084732217,
502.1794607549431,
514.1111009798041,
509.81499900059964,
521.7037700139749,
]

tcp_sender = [
37.70301457376722,
313.40755244755246,
422.0608,
460.3872,
498.75392,
499.9777644471106,
503.55872,
514.9088,
510.80735999999996,
523.1398640543782,
]

median_server = np.median(tcp_server)
median_sender = np.median(tcp_sender)
std_server = np.std(tcp_server)
std_sender = np.std(tcp_sender)

print("Medianwert von Sender: " + str(median_sender))
print("Medianwert von Server: " + str(median_server))
print("Standardabweichung von Sender: " + str(std_sender))
print("Standardabweichung von Server: " + str(std_server))

plt.plot(tcp_sender, tcp_server, '-ok')
plt.xlabel('Senderate kB/s')
plt.ylabel('Empfangsrate kB/s')
plt.title('TCP Netzwerk')
plt.show()
# Out:
# Medianwert von Sender: 499.3658422235553
# Medianwert von Server: 498.4441043700825
# Standardabweichung von Sender: 143.49320020445643
# Standardabweichung von Server: 143.1625744465129
