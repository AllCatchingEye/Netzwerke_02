# %%
from typing import List, Tuple
import logging as log
from datetime import datetime
import matplotlib.ticker as ticker
import matplotlib.animation as animation
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

server = [0.8698500440528634,
0.9735275273355073,
0.8678635677127035,
0.9025403239556692,
1.047163064453879]

sender = [1.1659726353361095,
1.208791208791209,
1.2176319430717533,
1.232,
1.2357787367595134]

median_sender = np.median(sender)
median_server = np.median(server)
std_sender = np.std(sender)
std_server = np.std(server)

print("Medianwert von Sender: " + str(median_sender))
print("Medianwert von Server: " + str(median_server))
print("Standardabweichung von Sender: " + str(std_sender))
print("Standardabweichung von Server: " + str(std_server))

plt.plot(sender, server, '-ok')
plt.xlabel('Senderate kB/s')
plt.ylabel('Empfangsrate kB/s')
plt.title('UDP Localhost')
#plt.plot(std_x, std_y, '-ok')
plt.show()
# Out:
# Medianwert von Sender: 1.2176319430717533
# Medianwert von Server: 0.9025403239556692
# Standardabweichung von Sender: 0.025003822315172734
# Standardabweichung von Server: 0.06903746808505776

# %%
sender = [0.8960631004,
0.96477775651,
0.98178727000,
1.01171855469,
1.01210256898
]

server = [0.94745222930,
1.00358422939,
1.04664000000,
1.03125622138,
1.05367399485
]
	
median_x = np.median(sender)
median_y = np.median(server)
std_x = np.std(sender)
std_y = np.std(server)

print("Medianwert von Sender: " + str(median_sender))
print("Medianwert von Server: " + str(median_server))
print("Standardabweichung von Sender: " + str(std_sender))
print("Standardabweichung von Server: " + str(std_server))

plt.plot(sender, server, '-ok')
plt.title('UDP Netzwerk')
plt.xlabel('Senderate kB/s')
plt.ylabel('Empfangsrate kB/s')
plt.show()
# Out:
# Medianwert von Sender: 1.2176319430717533
# Medianwert von Server: 0.9025403239556692
# Standardabweichung von Sender: 0.025003822315172734
# Standardabweichung von Server: 0.06903746808505776

# %%
tcp_server = [
984.504078817734,
2498.1881000000003,
2939.0770588235296,
2982.943880597015,
3074.726769230769,
2700.7734054054054,
3387.4107118644065,
3122.769375,
3633.768,
3506.2673684210527
]

tcp_sender = [
1098.9010989010987,
2500.0,
4255.31914893617,
4347.826086956521,
4545.454545454546,
4761.904761904762,
4761.904761904762,
4878.048780487805,
5405.405405405405,
5555.555555555556
]

median_server = np.median(tcp_server)
median_sender = np.median(tcp_sender)
std_server = np.std(tcp_server)
std_sender = np.std(tcp_sender)

print("Medianwert von Sender: " + str(median_sender))
print("Medianwert von Server: " + str(median_server))
print("Standardabweichung von Sender: " + str(std_sender))
print("Standardabweichung von Server: " + str(std_server))

plt.plot(tcp_sender, tcp_server, '-ok')
plt.xlabel('Senderate kB/s')
plt.ylabel('Empfangsrate kB/s')
plt.title('TCP Localhost')
plt.show()
# Out:
# Medianwert von Sender: 4653.679653679654
# Medianwert von Server: 3028.835324913892
# Standardabweichung von Sender: 1305.0519557223404
# Standardabweichung von Server: 714.1078606310859

# %%
tcp_server = [
1.209939393939394,
2.348705882352941,
4.994,
4.437333333333333,
3.3273333333333337,
3.328,
4.44,
7.992,
4.991,
4.436444444444445
]

tcp_sender = [
1.5384615384615385,
5.0,
8.0,
8.0, 
10.0,
10.0,
10.0,
10.0,
10.0,
13.333333333333334
]

median_server = np.median(tcp_server)
median_sender = np.median(tcp_sender)
std_server = np.std(tcp_server)
std_sender = np.std(tcp_sender)

print("Medianwert von Sender: " + str(median_sender))
print("Medianwert von Server: " + str(median_server))
print("Standardabweichung von Sender: " + str(std_sender))
print("Standardabweichung von Server: " + str(std_server))

plt.plot(tcp_sender, tcp_server, '-ok')
plt.xlabel('Senderate kB/s')
plt.ylabel('Empfangsrate kB/s')
plt.title('TCP Netzwerk')
plt.show()
# Out:
# Medianwert von Sender: 10.0
# Medianwert von Server: 4.436888888888889
# Standardabweichung von Sender: 3.094319411966735
# Standardabweichung von Server: 1.72250895242664
