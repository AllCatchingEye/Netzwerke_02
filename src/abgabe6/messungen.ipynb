# %%
from typing import List, Tuple
import logging as log
from datetime import datetime
import matplotlib.ticker as ticker
import matplotlib.animation as animation
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

y = [0.8698500440528634,
0.9735275273355073,
0.9025403239556692,
1.047163064453879,
0.8678635677127035]

x = [1.1659726353361095,
1.208791208791209,
1.232,
1.2357787367595134,
1.2176319430717533]

median_x = np.median(x)
median_y = np.median(y)
var_x = np.std(x)
var_y = np.std(y)

print(median_x)
print(median_y)
print(var_x)
print(var_y)

plt.plot(x, y, '-ok')
# Out:
# 1.2176319430717533
# 0.9025403239556692
# 0.025003822315172737
# 0.06903746808505776

# %%
x = [0.8960631004,
0.96477775651,
0.98178727000,
1.01171855469,
1.01210256898
]

y = [0.94745222930,
1.00358422939,
1.04664000000,
1.03125622138,
1.05367399485
]
	
median_x = np.median(x)
median_y = np.median(y)
var_x = np.std(x)
var_y = np.std(y)

print(median_x)
print(median_y)
print(var_x)
print(var_y)

plt.plot(x, y, '-ok')
# Out:
# 0.98178727
# 1.03125622138
# 0.04264229176484698
# 0.038581034345143254
